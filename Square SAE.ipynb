# %%
from AutoEncoders import SAE
from Utils import getAverageViTActivation, createImageDataloader, createImageDataset
from Training import trainSAEonViT
from Visualizations import plotActivation

import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from AutoEncoders import SAE
#       2 from Utils import getAverageViTActivation, createImageDataloader, createImageDataset
#       3 from Training import trainSAEonViT
#
# ImportError: cannot import name 'SAE' from 'AutoEncoders' (/Users/mawy/Desktop/Thesis/Code/AutoEncoders.py)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
data = createImageDataset('Square Dataset/imgs', 224, 224)

# %%
mact = getAverageViTActivation(data, device, samples = 32, clip_model_name = "ViT-B/16")
print("Shape of Activation: ", mact.shape)
plotActivation(mact)
# Out:
# Collecting ViT Activations: 100%|██████████| 32/32 [00:10<00:00,  2.93it/s]
# Shape of Activation:  torch.Size([768])

# %%
SAE = SAE(768, 32, mact)

# %%
dataloader = createImageDataloader('Square Dataset/imgs', 224, 224, bsize = 64)
trainSAEonViT(SAE, dataloader, device, epochs = 1)
# Out:
# Epoch 1:   0%|          | 0/250 [00:12<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 dataloader = createImageDataloader('Square Dataset/imgs', 224, 224, bsize = 64)
# ----> 2 trainSAEonViT(SAE, dataloader, device, epochs = 1)
#
# File ~/Desktop/Thesis/Code/Training.py:28, in trainSAEonViT(model, trainloader, device, epochs, alpha, lr, clip_model_name)
#      25 images = images.to(device)
#      27 with torch.no_grad():
# ---> 28     images_preprocessed = torch.stack([clip_preprocess(img) for img in images]).to(device)
#      30     hooked_cls_output.clear()
#      31     _ = clip_model.visual(images_preprocessed)
#
# File ~/Desktop/Thesis/Code/Training.py:28, in <listcomp>(.0)
#      25 images = images.to(device)
#      27 with torch.no_grad():
# ---> 28     images_preprocessed = torch.stack([clip_preprocess(img) for img in images]).to(device)
#      30     hooked_cls_output.clear()
#      31     _ = clip_model.visual(images_preprocessed)
#
# File /opt/anaconda3/envs/thesis/lib/python3.10/site-packages/torchvision/transforms/transforms.py:95, in Compose.__call__(self, img)
#      93 def __call__(self, img):
#      94     for t in self.transforms:
# ---> 95         img = t(img)
#      96     return img
#
# File /opt/anaconda3/envs/thesis/lib/python3.10/site-packages/clip/clip.py:76, in _convert_image_to_rgb(image)
#      75 def _convert_image_to_rgb(image):
# ---> 76     return image.convert("RGB")
#
# AttributeError: 'Tensor' object has no attribute 'convert'
